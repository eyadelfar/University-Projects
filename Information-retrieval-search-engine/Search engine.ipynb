# %% [markdown]
# ## Importing libraries

# %%
import numpy as np # for linear algebra , math equations
import math # for math
import pandas as pd # for dataframes
from sklearn.feature_extraction.text import TfidfVectorizer # to vectorize the tf_idf values
import os # read files from folder
import natsort as nt #to sort files in natural number order
from nltk.tokenize import word_tokenize # to make a list of strings
from nltk.corpus import stopwords # to remove unwanted words (very common)
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # PART 1

# %% [markdown]
# ### a) Read 10 files

# %%
path = 'C:/Users/Eyad/Desktop/AI course,Data Science/projects/IR CS/documents/'
os.chdir(path)

# %%
files = nt.natsorted(os.listdir())
files
# Out:
# ['1.txt',
#  '2.txt',
#  '3.txt',
#  '4.txt',
#  '5.txt',
#  '6.txt',
#  '7.txt',
#  '8.txt',
#  '9.txt',
#  '10.txt']

# %%
dicts = {}
keys = range(1,len(files)+1)
values = []
for file in files:
    with open(file , 'r', encoding='utf-8') as f:
        values.append(f.read())
for i in keys:
        dicts[i] = values[i-1]
print(dicts)
# Out:
# {1: 'antony brutus caeser cleopatra mercy worser', 2: 'antony brutus caeser calpurnia ', 3: 'mercy worser', 4: 'brutus caeser mercy worser', 5: 'caeser mercy worser', 6: 'antony caeser mercy ', 7: 'angels fools fear in rush to tread where', 8: 'angels fools fear in rush to tread where', 9: 'angels fools in rush to tread where', 10: 'fear in rush to tread where fools'}

# %%
def append_new_doc(doc,filenumber): # to be more dynamic
    with open(doc , 'r', encoding='utf-8') as f:
        dicts[filenumber] = f.read()

# %% [markdown]
# ### b ) Tokenization

# %%
def tokenize_query(query): 
    query = word_tokenize(query)
    return query

# %%
for i in dicts:
    dicts[i] = tokenize_query(dicts[i])
    print(dicts[i])
# Out:
# ['antony', 'brutus', 'caeser', 'cleopatra', 'mercy', 'worser']
# ['antony', 'brutus', 'caeser', 'calpurnia']
# ['mercy', 'worser']
# ['brutus', 'caeser', 'mercy', 'worser']
# ['caeser', 'mercy', 'worser']
# ['antony', 'caeser', 'mercy']
# ['angels', 'fools', 'fear', 'in', 'rush', 'to', 'tread', 'where']
# ['angels', 'fools', 'fear', 'in', 'rush', 'to', 'tread', 'where']
# ['angels', 'fools', 'in', 'rush', 'to', 'tread', 'where']
# ['fear', 'in', 'rush', 'to', 'tread', 'where', 'fools']

# %%
#Test
q = 'Hello im eyad'
q = tokenize_query(q)
q
# Out:
# ['Hello', 'im', 'eyad']

# %% [markdown]
# ## c) Apply stop words (except: in , to,where)

# %%
stopwords_edited = stopwords.words('english')
stopwords_edited.remove('in')
stopwords_edited.remove('to')
stopwords_edited.remove('where')

# %%
def remove_stop_words(query):
    query = [word for word in query if not word in stopwords_edited]
    return query

# %%
for i in dicts:
    dicts[i] = remove_stop_words(dicts[i])
    print(dicts[i])
# Out:
# ['antony', 'brutus', 'caeser', 'cleopatra', 'mercy', 'worser']
# ['antony', 'brutus', 'caeser', 'calpurnia']
# ['mercy', 'worser']
# ['brutus', 'caeser', 'mercy', 'worser']
# ['caeser', 'mercy', 'worser']
# ['antony', 'caeser', 'mercy']
# ['angels', 'fools', 'fear', 'in', 'rush', 'to', 'tread', 'where']
# ['angels', 'fools', 'fear', 'in', 'rush', 'to', 'tread', 'where']
# ['angels', 'fools', 'in', 'rush', 'to', 'tread', 'where']
# ['fear', 'in', 'rush', 'to', 'tread', 'where', 'fools']

# %%
all_words = []
for doc in dicts:
    for term in dicts[doc]:
        all_words.append(term)
all_words = sorted(all_words)

# %%
#test
q = 'Where are you at the to in from from in egypt'
q = tokenize_query(q)
q = remove_stop_words(q)
q
# Out:
# ['Where', 'to', 'in', 'in', 'egypt']

# %% [markdown]
# # PART 2

# %% [markdown]
# ### a) Building positional index

# %%
doc_no = 1
pos_idx = {}
def positional_indexing(doc):
    global doc_no
    global pos_idx
     #looping in each word in document
    if term in pos_idx:  #check if term is in dictionary already
        pos_idx[term][0] += 1    # if term is in dictionary the frequency of it will increase by 1
        if doc_no in pos_idx[term][1]: # if it was already in the same document
            pos_idx[term][1][doc_no].append(pos)   # it will append the other position index
        else:
            pos_idx[term][1][doc_no] = [pos] # if not it will create the first position it appeared in the document
    else:

        pos_idx[term]=[]   # if term is not in the document

        pos_idx[term].append(1) # it will append number one as it appeared for first time

        pos_idx[term].append({})  # it will append a dictionary next to the list to put term positions

        pos_idx[term][1][doc_no] = [pos] #it will put the position as a value in the key of document number

     # increase document number to change keys to be next in the next loop

# %%
doc_no = 1
pos_idx = {}
for doc in dicts: 
    for pos,term in enumerate(dicts[doc]):
        positional_indexing(doc)
    doc_no +=1
print(pos_idx)
# Out:
# {'antony': [3, {1: [0], 2: [0], 6: [0]}], 'brutus': [3, {1: [1], 2: [1], 4: [0]}], 'caeser': [5, {1: [2], 2: [2], 4: [1], 5: [0], 6: [1]}], 'cleopatra': [1, {1: [3]}], 'mercy': [5, {1: [4], 3: [0], 4: [2], 5: [1], 6: [2]}], 'worser': [4, {1: [5], 3: [1], 4: [3], 5: [2]}], 'calpurnia': [1, {2: [3]}], 'angels': [3, {7: [0], 8: [0], 9: [0]}], 'fools': [4, {7: [1], 8: [1], 9: [1], 10: [6]}], 'fear': [3, {7: [2], 8: [2], 10: [0]}], 'in': [4, {7: [3], 8: [3], 9: [2], 10: [1]}], 'rush': [4, {7: [4], 8: [4], 9: [3], 10: [2]}], 'to': [4, {7: [5], 8: [5], 9: [4], 10: [3]}], 'tread': [4, {7: [6], 8: [6], 9: [5], 10: [4]}], 'where': [4, {7: [7], 8: [7], 9: [6], 10: [5]}]}

# %% [markdown]
# ### b) Allow users to write queries

# %%
def return_matched_docs_ix(q):
    pos_idx_list = [[] for i in range(len(pos_idx))]
    for w in q: # looping every word in query
        
        try:
            
            for k in pos_idx[w][1].keys(): # looping key in keys in each term

                if pos_idx_list[k-1] != []:

                    if pos_idx_list[k-1][-1] == pos_idx[w][1][k][0]-1:
                        pos_idx_list[k-1].append(pos_idx[w][1][k][0])

                else:
                        pos_idx_list[k-1].append(pos_idx[w][1][k][0])

            
            for ix , lists in enumerate(pos_idx_list):
                if len(q) == len(lists):
                    print("Matched in doc number:" , ix+1)
        except KeyError:
            print("No matched document -> invalid input")

# %%
# test
q = "fools fear in"
q = tokenize_query(q)
q = remove_stop_words(q)
print(q)
return_matched_docs_ix(q)
# Out:
# ['fools', 'fear', 'in']
# Matched in doc number: 7
# Matched in doc number: 8

# %% [markdown]
# # Part 3

# %% [markdown]
# ### a) Term frequency

# %%
def get_term_freq(doc): # TF = total time word appeared in document
    words_found = dict.fromkeys(all_words , 0) #dictionary with all words frequencies are = 0
    for word in doc: # looping in each word in the document
        words_found[word] += 1 # if we found the word , we increase the value (0) to be (1)
    return words_found   # returning the new dictionary after getting all frequency

# %%
tf = pd.DataFrame()
for i in range(1 , len(dicts)+1):
    tf[i] =  pd.DataFrame(
                            get_term_freq(dicts[i]).values() ,
                            index = get_term_freq(dicts[i]).keys()
                         )
    
tf.columns = [f"DOC_{i}" for i in range(1,11)]
tf.style.background_gradient(cmap = "Blues")
# Out:
# <style type="text/css">
# #T_54577_row0_col0, #T_54577_row0_col1, #T_54577_row0_col2, #T_54577_row0_col3, #T_54577_row0_col4, #T_54577_row0_col5, #T_54577_row0_col9, #T_54577_row1_col2, #T_54577_row1_col3, #T_54577_row1_col4, #T_54577_row1_col6, #T_54577_row1_col7, #T_54577_row1_col8, #T_54577_row1_col9, #T_54577_row2_col2, #T_54577_row2_col4, #T_54577_row2_col5, #T_54577_row2_col6, #T_54577_row2_col7, #T_54577_row2_col8,
level0_col0" class="col_heading level0 col0" >DOC_1</th>
#       <th id="T_54577_level0_col1" class="col_heading level0 col1" >DOC_2</th>
#       <th id="T_54577_level0_col2" class="col_heading level0 col2" >DOC_3</th>
#       <th id="T_54577_level0_col3" class="col_heading level0 col3" >DOC_4</th>
#       <th id="T_54577_level0_col4" class="col_heading level0 col4" >DOC_5</th>
#       <th id="T_54577_level0_col5" class="col_heading level0 col5" >DOC_6</th>
#       <th id="T_54577_level0_col6" class="col_heading level0 col6" >DOC_7</th>
#       <th id="T_54577_level0_col7" class="col_heading level0 col7" >DOC_8</th>
#       <th id="T_54577_level0_col8" class="col_heading level0 col8" >DOC_9</th>
#       <th id="T_54577_level0_col9" class="col_heading level0 col9" >DOC_10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54577_level0_row0" class="row_heading level0 row0" >angels</th>
#       <td id="T_54577_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_54577_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_54577_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_54577_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_54577_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_54577_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_54577_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_54577_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_54577_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_54577_row0_col9" class="data row0 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_54577_level0_row1" class="row_heading level0 row1" >antony</th>
#       <td id="T_54577_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_54577_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_54577_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_54577_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_54577_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_54577_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_54577_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_54577_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_54577_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_54577_row1_col9" class="data row1 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_54577_level0_row2" class="row_heading level0 row2" >brutus</th>
#       <td id="T_54577_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_54577_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_54577_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_54577_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_54577_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_54577_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_54577_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_54577_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_54577_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_54577_row2_col9" class="data row2 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_54577_level0_row3" class="row_heading level0 row3" >caeser</th>
#       <td id="T_54577_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_54577_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_54577_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_54577_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_54577_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_54577_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_54577_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_54577_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_54577_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_54577_row3_col9" class="data row3 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_54577_level0_row4" class="row_heading level0 row4" >calpurnia</th>
#       <td id="T_54577_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_54577_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_54577_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_54577_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_54577_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_54577_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_54577_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_54577_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_54577_row4_col8" class="data row4 col8" >0</td>
#       <td id="T_54577_row4_col9" class="data row4 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_54577_level0_row5" class="row_heading level0 row5" >cleopatra</th>
#       <td id="T_54577_row5_col0" class="data row5 col0" >1</td>
#       <td id="T_54577_row5_col1" class="data row5 col1" >

# %% [markdown]
# ##### Weighted term frequency

# %%
def get_weighted_term_freq(x): # log(tf)+1    ## to decay the difference gap between documents 
    try:
        return math.log(x)+1
    except ValueError:
        return 0

# %%
wtf = tf.copy()

# %%
for i in range(1,len(dicts)+1):
    wtf[f"DOC_{i}"] = wtf[f"DOC_{i}"].apply(get_weighted_term_freq) #apply wtf to each cell in tf matrix
wtf.astype(int).style.background_gradient(cmap = "Blues")
# Out:
# <style type="text/css">
# #T_a05e2_row0_col0, #T_a05e2_row0_col1, #T_a05e2_row0_col2, #T_a05e2_row0_col3, #T_a05e2_row0_col4, #T_a05e2_row0_col5, #T_a05e2_row0_col9, #T_a05e2_row1_col2, #T_a05e2_row1_col3, #T_a05e2_row1_col4, #T_a05e2_row1_col6, #T_a05e2_row1_col7, #T_a05e2_row1_col8, #T_a05e2_row1_col9, #T_a05e2_row2_col2, #T_a05e2_row2_col4, #T_a05e2_row2_col5, #T_a05e2_row2_col6, #T_a05e2_row2_col7, #T_a05e2_row2_col8, #T_a05e2_row2_col9, #T_a05e2_row3_col2, #T_a05e2_row3_col6, #T_a05e2_row3_col7, #T_a05e2_row3_col8, #T_a05e2_row3_col9, #T_a05e2_row4_col0, #T_a05e2_row4_col2, #T_a05e2_row4_col3, #T_a05e2_row4_col4, #T_a05e2_row4_col5, #T_a05e2_row4_col6, #T_a05e2_row4_col7, #T_a05e2_row4_col8, #T_a05e2_row4_col9, #T_a05e2_row5_col1, #T_a05e2_row5_col2, #T_a05e2_row5_col3, #T_a05e2_row5_col4, #T_a05e2_row5_col5, #T_a05e2_row5_col6, #T_a05e2_row5_col7, #T_a05e2_row5_col8, #T_a05e2_row5_col9, #T_a05e2_row6_col0, #T_a05e2_row6_col1, #T_a05e2_row6_col2, #T_a05e2_row6_col3, #T_a05e2_row6_col4, #T_a05e2_row6_col5, #T_a05e2_row6_col8, #T_a05e2_row7_col0, #T_a05e2_row7_col1, #T_a05e2_row7_col2, #T_a05e2_row7_col3, #T_a05e2_row7_col4, #T_a05e2_row7_col5, #T_a05e2_row8_col0, #T_a05e2_row8_col1, #T_a05e2_row8_col2, #T_a05e2_row8_col3, #T_a05e2_row8_col4, #T_a05e2_row8_col5, #T_a05e2_row9_col1, #T_a05e2_row9_col6, #T_a05e2_row9_col7, #T_a05e2_row9_col8, #T_a05e2_row9_col9, #T_a05e2_row10_col0, #T_a05e2_row10_col1, #T_a05e2_row10_col2, #T_a05e2_row10_col3, #T_a05e2
row5_col0" class="data row5 col0" >1</td>
#       <td id="T_a05e2_row5_col1" class="data row5 col1" >

# %% [markdown]
# ### b) Inverse document frequency

# %%
idf_df = pd.DataFrame(index = get_term_freq(dicts[1]).keys() , columns=["df" , "idf"])

# %%
for i in idf_df.index: ## inverse document frequency -> used to decay the times documents are important to another document
    idf_df['df'][i] = pos_idx[i][0] #frequency of each term in all documents
    idf_df['idf'][i] = np.log10( len(dicts.keys()) / float(pos_idx[i][0]) ) # inverse document formula for each word

# %%
# type casting just to apply the colors
idf_df["df"] = idf_df["df"].astype(int)
idf_df["idf"] = idf_df["idf"].astype(float)

# %%
idf_df.style.background_gradient(cmap = "Blues" , axis= 0)
# Out:
# <style type="text/css">
# #T_cda15_row0_col0, #T_cda15_row1_col0, #T_cda15_row2_col0, #T_cda15_row6_col0 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_cda15_row0_col1, #T_cda15_row1_col1, #T_cda15_row2_col1, #T_cda15_row6_col1 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_cda15_row3_col0, #T_cda15_row4_col1, #T_cda15_row5_col1, #T_cda15_row9_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_cda15_row3_col1, #T_cda15_row4_col0, #T_cda15_row5_col0, #T_cda15_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_cda15_row7_col0, #T_cda15_row8_col0, #T_cda15_row10_col0, #T_cda15_row11_col0, #T_cda15_row12_col0, #T_cda15_row13_col0, #T_cda15_row14_col0 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_cda15_row7_col1, #T_cda15_row8_col1, #T_cda15_row10_col1, #T_cda15_row11_col1, #T_cda15_row12_col1, #T_cda15_row13_col1, #T_cda15_row14_col1 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# </style>
# <table id="T_cda15">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cda15_level0_col0" class="col_heading level0 col0" >df</th>
#       <th id="T_cda15_level0_col1" class="col_heading level0 col1" >idf</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cda15_level0_row0" class="row_heading level0 row0" >angels</th>
#       <td id="T_cda15_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_cda15_row0_col1" class="data row0 col1" >0.522879</td>
#     </tr>
#     <tr>
#       <th id="T_cda15_level0_row1" class="row_heading level0 row1" >antony</th>
#       <td id="T_cda15_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_cda15_row1_col1" class="data row1 col1" >0.522879</td>
#     </tr>
#     <tr>
#       <th id="T_cda15_level0_row2" class="row_heading level0 row2" >brutus</th>
#       <td id="T_cda15_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_cda15_row2_col1" class="data row2 col1" >0.522879</td>
#     </tr>
#     <tr>
#       <th id="T_cda15_level0_row3" class="row_heading level0 row3" >caeser</th>
#       <td id="T_cda15_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_cda15_row3_col1" class="data row3 col1" >0.301030</td>
#     </tr>
#     <tr>
#       <th id="T_cda15_level0_row4" class="row_heading level0 row4" >calpurnia</th>
#       <td id="T_cda15_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_cda15_row4_col1" class="data row4 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cda15_level0_row5" class="row_heading level0 row5" >cleopatra</th>
#       <td id="T_cda15_row5_col0" class="data row5 col0" >1</td>
#       <td id="T_cda15_row5_col1" class="data row5 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cda15_level0_row6" class="row_heading level0 row6" >fear</th>
#       <td id="T_cda15_row6_col0" class="data row6 col0" >3</td>
#       <td id="T_cda15_row6_col1" class="data row6 col1" >0.522879</td>
#     </tr>
#     <tr>
#       <th id="T_cda15_level0_row7" class="row_heading level0 row7" >fools</th>
#       <td id="T_cda15_row7_col0" class="data row7 col0" >4</td>
#       <td id="T_cda15_row7_col1" class="data row7 col1" >0.397940</td>
#     </tr>
#     <tr>
#       <th id="T_cda15_level0_row8" class="row_heading level0 row8" >in</th>
#       <td id="T_cda15_row8_col0" class="data row8 col0" >4</td>
#       <td id="T_cda15_row8_col1" class="data row8 col1" >0.397940</td>
#     </tr>
#     <tr>
#       <th id="T_cda15_level0_row9" class="row_heading level0 row9" >mercy</th>
#       <td id="T_cda15_row9_col0" class="data row9 col0" >5</td>
#       <td id="T_cda15_row9_col1" class="data row9 col1" >0.301030</td>
#     </tr>
#     <tr>
#       <th id="T_cda15_level0_row10" class="row_heading level0 row10" >rush</th>
#       <td id="T_cda15_row10_col0" class="data row10 col0" >4</td>
#       <td id="T_cda15_row10_col1" class="data row10 col1" >0.397940</td>
#     </tr>
#     <tr>
#       <th id="T_cda15_level0_row11" class="row_heading level0 row11" >to</th>
#       <td id="T_cda15_row11_col0" class="data row11 col0" >4</td>
#       <td id="T_cda15_row11_col1" class="data row11 col1" >0.397940</td>
#     </tr>
#     <tr>
#       <th id="T_cda15_level0_row12" class="row_heading level0 row12" >tread</th>
#       <td id="T_cda15_row12_col0" class="data row12 col0" >4</td>
#       <td id="T_cda15_row12_col1" class="data row12 col1" >0.397940</td>
#     </tr>
#     <tr>
#       <th id="T_cda15_level0_row13" class="row_heading level0 row13" >where</th>
#       <td id="T_cda15_row13_col0" class="data row13 col0" >4</td>
#       <td id="T_cda15_row13_col1" class="data row13 col1" >0.397940</td>
#     </tr>
#     <tr>
#       <th id="T_cda15_level0_row14" class="row_heading level0 row14" >worser</th>
#       <td id="T_cda15_row14_col0" class="data row14 col0" >4</td>
#       <td id="T_cda15_row14_col1" class="data row14 col1" >0.397940</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### c) Term frequency - Inverse document frequency

# %%
tf_idf = tf.multiply(idf_df["idf"] , axis = 0) # axis = 0 to multiply rows not columns

# %%
tf_idf.style.background_gradient(cmap = "Blues" , axis= 0)
# Out:
# <style type="text/css">
# #T_8a866_row0_col0, #T_8a866_row0_col1, #T_8a866_row0_col2, #T_8a866_row0_col3, #T_8a866_row0_col4, #T_8a866_row0_col5, #T_8a866_row0_col9, #T_8a866_row1_col2, #T_8a866_row1_col3, #T_8a866_row1_col4, #T_8a866_row1_col6, #T_8a866_row1_col7, #T_8a866_row1_col8, #T_8a866_row1_col9, #T_8a866_row2_col2, #T_8a866_row2_col4, #T_8a866_row2_col5, #T_8a866_row2_col6, #T_8a866_row2_col7, #T_8a866_row2_col8, #T_8a866_row2_col9, #T_8a866_row3_col2, #T_8a866_row3_col6, #T_8a866_row3_col7, #T_8a866_row3_col8, #T_8a866_row3_col9, #T_8a866_row4_col0, #T_8a866_row4_col2, #T_8a866_row4_col3, #T_8a866_row4_col4, #T_8a866_row4_col5, #T_8a866_row4_col6, #T_8a866_row4_col7, #T_8a866_row4_col8, #T_8a866_row4_col9, #T_8a866_row5_col1, #T_8a866_row5_col2, #T_8a866_row5_col3, #T_8a866_row5_col4, #T_8a866_row5_col5, #T_8a866_row5_col6, #T_8a866_row5_col7, #T_8a866_row5_col8, #T_8a866_row5_col9, #T_8a866_row6_col0, #T_8a866_row6_col1, #T_8a866_row6_col2, #T_8a866_row6_col3, #T_8a866_row6_col4, #T_8a866_row6_col5, #T_8a866_row6_col8, #T_8a866_row7_col0, #T_8a866_row7_col1, #T_8a866_row7_col2, #T_8a866_row7_col3, #T_8a866_row7_col4, #T_8a866_row7_col5, #T_8a866_row8_col0, #T_8a866_row8_col1, #T_8a866_row8_col2, #T_8a866_row8_col3, #T_8a866_row8_col4, #T_8a866_row8_col5, #T_8a866_row9_col1, #T_8a866_row9_col6, #T_8a866_row9_col7, #T_8a866_row9_col8, #T_8a866_row9_col9, #T_8a866_row10_col0, #T_8a866_row10_col1, #T_8a866_row10_col2, #T_8a866_row10_col3, #T_8a866_row10_col4, #T_8a866_row10_col5, #T_8a866_row11_col0, #T_8a866_row11_col1, #T_8a866_row11_col2, #T_8a866_row11_col3, #T_8a866_row11_col4, #T_8a866_row11_col5, #T_8a866_row12_col0, #T_8a866_row12_col1, #T_8a866_row12_col2, #T_8a866_row12_col3, #T_8a866_row12_col4, #T_8a866_row12_col5, #T_8a866_row13_col0, #T_8a866_row13_col1, #T_8a866_row13_col2, #T_8a866_row13_col3, #T_8a866_row13_col4, #T_8a866_row13_col5, #T_8a866_row14_col1, #T_8a866_row14_col5, #T_8a866_row14_col6, #T_8a866_row14_col7, #T_8a866_row14_col8, #T_8a866_row14_col9 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8a866_row0_col6, #T_8a866_row0_col7, #T_8a866_row0_col8, #T_8a866_row1_col5, #T_8a866_row2_col3, #T_8a866_row4_col1, #T_8a866_row5_col0, #T_8a866_row6_col6, #T_8a866_row6_col7, #T_8a866_row6_col9, #T_8a866_row14_col2, #T_8a866_row14_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8a866_row1_col0, #T_8a866_row1_col1, #T_8a866_row2_col0, #T_8a866_row2_col1 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_8a866_row3_col0, #T_8a866_row3_col1, #T_8a866_row9_col0 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_8a866_row3_col3, #T_8a866_row3_col5, #T_8a866_row9_col3, #T_8a866_row9_col5 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_8a866_row3_col4, #T_8a866_row9_col2, #T_8a866_row9_col4 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_8a866_row7_col6, #T_8a866_row7_col7, #T_8a866_row7_col8, #T_8a866_row7_col9, #T_8a866_row8_col6, #T_8a866_row8_col7, #T_8a866_row8_col8, #T_8a866_row8_col9, #T_8a866_row10_col6, #T_8a866_row10_col7, #T_8a866_row10_col8, #T_8a866_row10_col9, #T_8a866_row11_col6, #T_8a866_row11_col7, #T_8a866_row11_col8, #T_8a866_row11_col9, #T_8a866_row12_col6, #T_8a866_row12_col7, #T_8a866_row12_col8, #T_8a866_row12_col9, #T_8a866_row13_col6, #T_8a866_row13_col7, #T_8a866_row13_col8, #T_8a866_row13_col9, #T_8a866_row14_col3 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_8a866_row14_col0 {
#   background-color: #95c5df;
#   color: #000000;
# }
# </style>
# <table id="T_8a866">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a866_level0_col0" class="col_heading level0 col0" >DOC_1</th>
#       <th id="T_8a866_level0_col1" class="col_heading level0 col1" >DOC_2</th>
#       <th id="T_8a866_level0_col2" class="col_heading level0 col2" >DOC_3</th>
#       <th id="T_8a866_level0_col3" class="col_heading level0 col3" >DOC_4</th>
#       <th id="T_8a866_level0_col4" class="col_heading level0 col4" >DOC_5</th>
#       <th id="T_8a866_level0_col5" class="col_heading level0 col5" >DOC_6</th>
#       <th id="T_8a866_level0_col6" class="col_heading level0 col6" >DOC_7</th>
#       <th id="T_8a866_level0_col7" class="col_heading level0 col7" >DOC_8</th>
#       <th id="T_8a866_level0_col8" class="col_heading level0 col8" >DOC_9</th>
#       <th id="T_8a866_level0_col9" class="col_heading level0 col9" >DOC_10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a866_level0_row0" class="row_heading level0 row0" >angels</th>
#       <td id="T_8a866_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_8a866_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_8a866_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_8a866_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_8a866_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_8a866_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_8a866_row0_col6" class="data row0 col6" >0.522879</td>
#       <td id="T_8a866_row0_col7" class="data row0 col7" >0.522879</td>
#       <td id="T_8a866_row0_col8" class="data row0 col8" >0.522879</td>
#       <td id="T_8a866_row0_col9" class="data row0 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8a866_level0_row1" class="row_heading level0 row1" >antony</th>
#       <td id="T_8a866_row1_col0" class="data row1 col0" >0.522879</td>
#       <td id="T_8a866_row1_col1" class="data row1 col1" >0.522879</td>
#       <td id="T_8a866_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_8a866_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_8a866_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_8a866_row1_col5" class="data row1 col5" >0.522879</td>
#       <td id="T_8a866_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_8a866_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_8a866_row1_col8" class="data row1 col8" >0.000000</td>
#       <td id="T_8a866_row1_col9" class="data row1 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8a866_level0_row2" class="row_heading level0 row2" >brutus</th>
#       <td id="T_8a866_row2_col0" class="data row2 col0" >0.522879</td>
#       <td id="T_8a866_row2_col1" class="data row2 col1" >0.522879</td>
#       <td id="T_8a866_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_8a866_row2_col3" class="data row2 col3" >0.522879</td>
#       <td id="T_8a866_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_8a866_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_8a866_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_8a866_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_8a866_row2_col8" class="data row2 col8" >0.000000</td>
#       <td id="T_8a866_row2_col9" class="data row2 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8a866_level0_row3" class="row_heading level0 row3" >caeser</th>
#       <td id="T_8a866_row3_col0" class="data row3 col0" >0.301030</td>
#       <td id="T_8a866_row3_col1" class="data row3 col1" >0.301030</td>
#       <td id="T_8a866_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_8a866_row3_col3" class="data row3 col3" >0.301030</td>
#       <td id="T_8a866_row3_col4" class="data row3 col4" >0.301030</td>
#       <td id="T_8a866_row3_col5" class="data row3 col5" >0.301030</td>
#       <td id="T_8a866_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_8a866_row3_col7" class="data row3 col7" >0.000000</td>
#       <td id="T_8a866_row3_col8" class="data row3 col8" >0.000000</td>
#       <td id="T_8a866_row3_col9" class="data row3 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8a866_level0_row4" class="row_heading level0 row4" >calpurnia</th>
#       <td id="T_8a866_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_8a866_row4_col1" class="data row4 col1" >1.000000</td>
#       <td id="T_8a866_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_8a866_row4_col3" class="data row4 col3" >0.000000</td>

# %% [markdown]
# ### Document length & Normalized tf_idf

# %% [markdown]
# ##### Document length

# %%
doc_length = pd.DataFrame()

# %%
def get_doc_length(col):
    return np.sqrt(tf_idf[col].apply(lambda x: x**2).sum())

# %%
for col in tf_idf.columns:
    doc_length.loc[ 0 , col + '_length'] = get_doc_length(col)

# %%
doc_length = doc_length.T

# %%
doc_length.columns = ['']

# %%
doc_length.style.background_gradient(cmap = 'Blues')
# Out:
# <style type="text/css">
# #T_8e1d5_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8e1d5_row1_col0 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_8e1d5_row2_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8e1d5_row3_col0 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_8e1d5_row4_col0 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_8e1d5_row5_col0 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_8e1d5_row6_col0, #T_8e1d5_row7_col0 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_8e1d5_row8_col0, #T_8e1d5_row9_col0 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8e1d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e1d5_level0_col0" class="col_heading level0 col0" ></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e1d5_level0_row0" class="row_heading level0 row0" >DOC_1_length</th>
#       <td id="T_8e1d5_row0_col0" class="data row0 col0" >1.373462</td>
#     </tr>
#     <tr>
#       <th id="T_8e1d5_level0_row1" class="row_heading level0 row1" >DOC_2_length</th>
#       <td id="T_8e1d5_row1_col0" class="data row1 col0" >1.279618</td>
#     </tr>
#     <tr>
#       <th id="T_8e1d5_level0_row2" class="row_heading level0 row2" >DOC_3_length</th>
#       <td id="T_8e1d5_row2_col0" class="data row2 col0" >0.498974</td>
#     </tr>
#     <tr>
#       <th id="T_8e1d5_level0_row3" class="row_heading level0 row3" >DOC_4_length</th>
#       <td id="T_8e1d5_row3_col0" class="data row3 col0" >0.782941</td>
#     </tr>
#     <tr>
#       <th id="T_8e1d5_level0_row4" class="row_heading level0 row4" >DOC_5_length</th>
#       <td id="T_8e1d5_row4_col0" class="data row4 col0" >0.582747</td>
#     </tr>
#     <tr>
#       <th id="T_8e1d5_level0_row5" class="row_heading level0 row5" >DOC_6_length</th>
#       <td id="T_8e1d5_row5_col0" class="data row5 col0" >0.674270</td>
#     </tr>
#     <tr>
#       <th id="T_8e1d5_level0_row6" class="row_heading level0 row6" >DOC_7_length</th>
#       <td id="T_8e1d5_row6_col0" class="data row6 col0" >1.223496</td>
#     </tr>
#     <tr>
#       <th id="T_8e1d5_level0_row7" class="row_heading level0 row7" >DOC_8_length</th>
#       <td id="T_8e1d5_row7_col0" class="data row7 col0" >1.223496</td>
#     </tr>
#     <tr>
#       <th id="T_8e1d5_level0_row8" class="row_heading level0 row8" >DOC_9_length</th>
#       <td id="T_8e1d5_row8_col0" class="data row8 col0" >1.106137</td>
#     </tr>
#     <tr>
#       <th id="T_8e1d5_level0_row9" class="row_heading level0 row9" >DOC_10_length</th>
#       <td id="T_8e1d5_row9_col0" class="data row9 col0" >1.106137</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### Normalized term freq inverse doc freq

# %%
normalized_tfidf = pd.DataFrame()

# %%
def get_normalized_tf_idf(col, x):
    try:
        return x / doc_length.loc[col + '_length'].values[0] # x -> cell
    except ZeroDivisionError:
        return 0

# %%
for col in tf_idf.columns:
    normalized_tfidf[col] = tf_idf[col].apply(lambda x: get_normalized_tf_idf(col , x))

# %%
normalized_tfidf.style.background_gradient(cmap = 'Blues' , axis= 0)
# Out:
# <style type="text/css">
# #T_421a3_row0_col0, #T_421a3_row0_col1, #T_421a3_row0_col2, #T_421a3_row0_col3, #T_421a3_row0_col4, #T_421a3_row0_col5, #T_421a3_row0_col9, #T_421a3_row1_col2, #T_421a3_row1_col3, #T_421a3_row1_col4, #T_421a3_row1_col6, #T_421a3_row1_col7, #T_421a3_row1_col8, #T_421a3_row1_col9, #T_421a3_row2_col2, #T_421a3_row2_col4, #T_421a3_row2_col5, #T_421a3_row2_col6, #T_421a3_row2_col7, #T_421a3_row2_col8, #T_421a3_row2_col9, #T_421a3_row3_col2, #T_421a3_row3_col6, #T_421a3_row3_col7, #T_421a3_row3_col8, #T_421a3_row3_col9, #T_421a3_row4_col0, #T_421a3_row4_col2, #T_421a3_row4_col3, #T_421a3_row4_col4, #T_421a3_row4_col5, #T_421a3_row4_col6, #T_421a3_row4_col7, #T_421a3_row4_col8, #T_421a3_row4_col9, #T_421a3_row5_col1, #T_421a3_row5_col2, #T_421a3_row5_col3, #T_421a3_row5_col4, #T_421a3_row5_col5, #T_421a3_row5_col6, #T_421a3_row5_col7, #T_421a3_row5_col8, #T_421a3_row5_col9, #T_421a3_row6_col0, #T_421a3_row6_col1, #T_421a3_row6_col2, #T_421a3_row6_col3, #T_421a3_row6_col4, #T_421a3_row6_col5, #T_421a3_row6_col8, #T_421a3_row7_col0, #T_421a3_row7_col1, #T_421a3_row7_col2, #T_421a3_row7_col3, #T_421a3_row7_col4, #T_421a3_row7_col5, #T_421a3_row8_col0, #T_421a3_row8_col1, #T_421a3_row8_col2, #T_421a3_row8_col3, #T_421a3_row8_col4, #T_421a3_row8_col5, #T_421a3_row9_col1, #T_421a3_row9_col6, #T_421a3_row9_col7, #T_421a3_row9_col8, #T_421a3_row9_col9, #T_421a3_row10_col0, #T_421a3_row10_col1, #T_421a3_row10_col2, #T_421a3_row10_col3, #T_421a3_row10_col4, #T_421a3_row10_col5, #T_421a3_row11_col0, #T_421a3_row11_col1, #T_421a3_row11_col2, #T_421a3_row11_col3, #T_421a3_row11_col4, #T_421a3_row11_col5, #T_421a3_row12_col0, #T_421a3_row12_col1, #T_421a3_row12_col2, #T_421a3_row12_col3, #T_421a3_row12_col4, #T_421a3_row12_col5, #T_421a3_row13_col0, #T_421a3_row13_col1, #T_421a3_row13_col2, #T_421a3_row13_col3, #T_421a3_row13_col4, #T_421a3_row13_col5, #T_421a3_row14_col1, #T_421a3_row14_col5, #T_421a3_row14_col6, #T_421a3_row14_col7, #T_421a3_row14_col8, #T_421a3_row14_col9 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_421a3_row0_col6, #T_421a3_row0_col7, #T_421a3_row0_col8, #T_421a3_row1_col5, #T_421a3_row2_col3, #T_421a3_row4_col1, #T_421a3_row5_col0, #T_421a3_row6_col6, #T_421a3_row6_col7, #T_421a3_row6_col9, #T_421a3_row14_col2, #T_421a3_row14_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_421a3_row1_col0, #T_421a3_row1_col1, #T_421a3_row2_col0, #T_421a3_row2_col1 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_421a3_row3_col0, #T_421a3_row3_col1, #T_421a3_row9_col0 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_421a3_row3_col3, #T_421a3_row3_col5, #T_421a3_row9_col3, #T_421a3_row9_col5 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_421a3_row3_col4, #T_421a3_row9_col2, #T_421a3_row9_col4 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_421a3_row7_col6, #T_421a3_row7_col7, #T_421a3_row7_col8, #T_421a3_row7_col9, #T_421a3_row8_col6, #T_421a3_row8_col7, #T_421a3_row8_col8, #T_421a3_row8_col9, #T_421a3_row10_col6, #T_421a3_row10_col7, #T_421a3_row10_col8, #T_421a3_row10_col9, #T_421a3_row11_col6, #T_421a3_row11_col7, #T_421a3_row11_col8, #T_421a3_row11_col9, #T_421a3_row12_col6, #T_421a3_row12_col7, #T_421a3_row12_col8, #T_421a3_row12_col9, #T_421a3_row13_col6, #T_421a3_row13_col7, #T_421a3_row13_col8, #T_421a3_row13_col9, #T_421a3_row14_col3 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_421a3_row14_col0 {
#   background-color: #95c5df;
#   color: #000000;
# }
# </style>
# <table id="T_421a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_421a3_level0_col0" class="col_heading level0 col0" >DOC_1</th>
#       <th id="T_421a3_level0_col1" class="col_heading level0 col1" >DOC_2</th>
#       <th id="T_421a3_level0_col2" class="col_heading level0 col2" >DOC_3</th>
#       <th id="T_421a3_level0_col3" class="col_heading level0 col3" >DOC_4</th>
#       <th id="T_421a3_level0_col4" class="col_heading level0 col4" >DOC_5</th>
#       <th id="T_421a3_level0_col5" class="col_heading level0 col5" >DOC_6</th>
#       <th id="T_421a3_level0_col6" class="col_heading level0 col6" >DOC_7</th>
#       <th id="T_421a3_level0_col7" class="col_heading level0 col7" >DOC_8</th>
#       <th id="T_421a3_level0_col8" class="col_heading level0 col8" >DOC_9</th>
#       <th id="T_421a3_level0_col9" class="col_heading level0 col9" >DOC_10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_421a3_level0_row0" class="row_heading level0 row0" >angels</th>
#       <td id="T_421a3_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_421a3_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_421a3_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_421a3_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_421a3_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_421a3_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_421a3_row0_col6" class="data row0 col6" >0.427365</td>
#       <td id="T_421a3_row0_col7" class="data row0 col7" >0.427365</td>
#       <td id="T_421a3_row0_col8" class="data row0 col8" >0.472707</td>
#       <td id="T_421a3_row0_col9" class="data row0 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_421a3_level0_row1" class="row_heading level0 row1" >antony</th>
#       <td id="T_421a3_row1_col0" class="data row1 col0" >0.380701</td>
#       <td id="T_421a3_row1_col1" class="data row1 col1" >0.408621</td>
#       <td id="T_421a3_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_421a3_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_421a3_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_421a3_row1_col5" class="data row1 col5" >0.775474</td>
#       <td id="T_421a3_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_421a3_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_421a3_row1_col8" class="data row1 col8" >0.000000</td>
#       <td id="T_421a3_row1_col9" class="data row1 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_421a3_level0_row2" class="row_heading level0 row2" >brutus</th>
#       <td id="T_421a3_row2_col0" class="data row2 col0" >0.380701</td>
#       <td id="T_421a3_row2_col1" class="data row2 col1" >0.408621</td>
#       <td id="T_421a3_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_421a3_row2_col3" class="data row2 col3" >0.667839</td>
#       <td id="T_421a3_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_421a3_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_421a3_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_421a3_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_421a3_row2_col8" class="data row2 col8" >0.000000</td>
#       <td id="T_421a3_row2_col9" class="data row2 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_421a3_level0_row3" class="row_heading level0 row3" >caeser</th>
#       <td id="T_421a3_row3_col0" class="data row3 col0" >0.219176</td>
#       <td id="T_421a3_row3_col1" class="data row3 col1" >0.235250</td>
#       <td id="T_421a3_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_421a3_row3_col3" class="data row3 col3" >0.384486</td>
#       <td id="T_421a3_row3_col4" class="data row3 col4" >0.516570</td>
#       <td id="T_421a3_row3_col5" class="data row3 col5" >0.446453</td>
#       <td id="T_421a3_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_421a3_row3_col7" class="data row3 col7" >0.000000</td>
#       <td id="T_421a3_row3_col8" class="data row3 col8" >0.000000</td>
#       <td id="T_421a3_row3_col9" class="data row3 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_421a3_level0_row4" class="row_heading level0 row4" >calpurnia</th>
#       <td id="T_421a3_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_421a3_row4_col1" class="data row4 col1" >0.781483</td>
#       <td id="T_421a3_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_421a3_row4_col3" class="data row4 col3" >0.000000</td>

# %% [markdown]
# ### d) Cosine similarity & Ranking documents

# %%
docs_cos = list(dicts.values())

# %%
for i in range(len(docs_cos)):
    docs_cos[i] = ' '.join(docs_cos[i])

# %%
vectorizer = TfidfVectorizer()

# %%
df = vectorizer.fit_transform(docs_cos).T.toarray() #dataframe for vectorizer

# %%
df = pd.DataFrame(df , index= vectorizer.get_feature_names())

# %%
df.style.background_gradient(cmap = 'Blues' , axis = 0)
# Out:
# <style type="text/css">
# #T_7629d_row0_col0, #T_7629d_row0_col1, #T_7629d_row0_col2, #T_7629d_row0_col3, #T_7629d_row0_col4, #T_7629d_row0_col5, #T_7629d_row0_col9, #T_7629d_row1_col2, #T_7629d_row1_col3, #T_7629d_row1_col4, #T_7629d_row1_col6, #T_7629d_row1_col7, #T_7629d_row1_col8, #T_7629d_row1_col9, #T_7629d_row2_col2, #T_7629d_row2_col4, #T_7629d_row2_col5, #T_7629d_row2_col6, #T_7629d_row2_col7, #T_7629d_row2_col8, #T_7629d_row2_col9, #T_7629d_row3_col2, #T_7629d_row3_col6, #T_7629d_row3_col7, #T_7629d_row3_col8, #T_7629d_row3_col9, #T_7629d_row4_col0, #T_7629d_row4_col2, #T_7629d_row4_col3, #T_7629d_row4_col4, #T_7629d_row4_col5, #T_7629d_row4_col6, #T_7629d_row4_col7, #T_7629d_row4_col8, #T_7629d_row4_col9, #T_7629d_row5_col1, #T_7629d_row5_col2, #T_7629d_row5_col3, #T_7629d_row5_col4, #T_7629d_row5_col5, #T_7629d_row5_col6, #T_7629d_row5_col7, #T_7629d_row5_col8, #T_7629d_row5_col9, #T_7629d_row6_col0, #T_7629d_row6_col1, #T_7629d_row6_col2, #T_7629d_row6_col3, #T_7629d_row6_col4, #T_7629d_row6_col5, #T_7629d_row6_col8, #T_7629d_row7_col0, #T_7629d_row7_col1, #T_7629d_row7_col2, #T_7629d_row7_col3, #T_7629d_row7_col4, #T_7629d_row7_col5, #T_7629d_row8_col0, #T_7629d_row8_col1, #T_7629d_row8_col2, #T_7629d_row8_col3, #T_7629d_row8_col4, #T_7629d_row8_col5, #T_7629d_row9_col1, #T_7629d_row9_col6, #T_7629d_row9_col7, #T_7629d_row9_col8, #T_7629d_row9_col9, #T_7629d_row10_col0, #T_7629d_row10_col1, #T_7629d_row10_col2, #T_7629d_row10_col3, #T_7629d_row10_col4, #T_7629d_row10_col5, #T_7629d_row11_col0, #T_7629d_row11_col1, #T_7629d_row11_col2, #T_7629d_row11_col3, #T_7629d_row11_col4, #T_7629d_row11_col5, #T_7629d_row12_col0, #T_7629d_row12_col1, #T_7629d_row12_col2, #T_7629d_row12_col3, #T_7629d_row12_col4, #T_7629d_row12_col5, #T_7629d_row13_col0, #T_7629d_row13_col1, #T_7629d_row13_col2, #T_7629d_row13_col3, #T_7629d_row13_col4, #T_7629d_row13_col5, #T_7629d_row14_col1, #T_7629d_row14_col5, #T_7629d_row14_col6, #T_7629d_row14_col7, #T_7629d_row14_col8, #T_7629d_row14_col9 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_
_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_7629d_row4_col4" class="

# %%
def get_relevant_docs(q, df): #query , dataframe(vectorizer)
    
    print("query is :", q)
    q = tokenize_query(q)
    q = ' '.join(remove_stop_words(q))
    print("query read as :", q)
    print("\n------------------\n"*3)
    
    q = [q]
    q_vec = vectorizer.transform(q).toarray().reshape(df.shape[0])
    sim = {}
    for i in range(10):
        sim[i] = np.dot(df.loc[:, i].values, q_vec) / np.linalg.norm(df.loc[:, i]) * np.linalg.norm(q_vec)
    sim_sorted = sorted(sim.items(), key=lambda x: x[1], reverse=True)
    
    print('\033[1m' + "Most relevant documents:\n")
    returned_docs = []
    print("Cosine similarity: (Query , Document number) ->(Score) : \n")
    for k, v in sim_sorted: #key , value
        if v != 0.0:
            returned_docs.append(k+1)
            print(f"({' '.join(q)} , {k+1}) -> {v}")
            print(f"Document: {' '.join(dicts[k+1])}" , end='\n\n')
    print("Returned documents: " , returned_docs)
    
    return returned_docs

# %%
def calc_query_data(q_entered , ret_docs):
    q_entered = [word for word in q_entered.split() if word in list(tf.index)]
    q_entered = ' '.join(q_entered)
    q = pd.DataFrame(index=tf.index)
    q['tf'] = [ 1 if i in q_entered.split() else 0 for i in list(tf.index) ]
    q["wtf"] = [ get_weighted_term_freq(i) for i in q["tf"] ] 
    q["idf"] =  q["wtf"] * idf_df["idf"]
    q['tfidf'] = q['tf'] * q['idf']
    q["norm"] = [(float(q["idf"].iloc[i]) / np.sqrt(sum(q['idf'].values**2))) for i in range(len(q))]


    prod = normalized_tfidf.multiply(q['wtf'] , axis = 0).multiply(q['norm'] , axis = 0)
    prod = prod.loc[q_entered.split() , [f"DOC_{i}" for i in ret_docs]]
    prod = prod.append(prod.sum(numeric_only=True).rename("Sum"))
    for col in prod.columns:
        if 0 in prod[col].values:
            prod.drop( col , axis = 1 ,inplace = True)

    q_len = np.sqrt(sum([x**2 for x in q["idf"].loc[q_entered.split()]]))

    return [  q.loc[q_entered.split() , :] , q_len , prod]

# %% [markdown]
# ## Search engine

# %%
query = input()
# Out:
# fools fear in

# %%
get_docs = get_relevant_docs(query, df)
# Out:
# query is : fools fear in
# query read as : fools fear in
#
# ------------------
#
# ------------------
#
# ------------------
#
# Most relevant documents:
#
# Cosine similarity: (Query , Document number) ->(Score) :
#
# (fools fear in , 10) -> 0.6703901383545914
# Document: fear in rush to tread where fools
#
# (fools fear in , 7) -> 0.618683750721479
# Document: angels fools fear in rush to tread where
#
# (fools fear in , 8) -> 0.618683750721479
# Document: angels fools fear in rush to tread where
#
# (fools fear in , 9) -> 0.4106392911359427
# Document: angels fools in rush to tread where
#
# Returned documents:  [10, 7, 8, 9]

# %% [markdown]
# # ----------------

# %%
# query data
calc_query_data(query , get_docs)[0].style.background_gradient(cmap = "Reds" , axis= 0)
# Out:
# <style type="text/css">
# #T_670fa_row0_col0, #T_670fa_row0_col1, #T_670fa_row0_col2, #T_670fa_row0_col3, #T_670fa_row0_col4, #T_670fa_row1_col0, #T_670fa_row1_col1, #T_670fa_row2_col0, #T_670fa_row2_col1, #T_670fa_row2_col2, #T_670fa_row2_col3, #T_670fa_row2_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_670fa_row1_col2, #T_670fa_row1_col3, #T_670fa_row1_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_670fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_670fa_level0_col0" class="col_heading level0 col0" >tf</th>
#       <th id="T_670fa_level0_col1" class="col_heading level0 col1" >wtf</th>
#       <th id="T_670fa_level0_col2" class="col_heading level0 col2" >idf</th>
#       <th id="T_670fa_level0_col3" class="col_heading level0 col3" >tfidf</th>
#       <th id="T_670fa_level0_col4" class="col_heading level0 col4" >norm</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_670fa_level0_row0" class="row_heading level0 row0" >fools</th>
#       <td id="T_670fa_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_670fa_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_670fa_row0_col2" class="data row0 col2" >0.397940</td>
#       <td id="T_670fa_row0_col3" class="data row0 col3" >0.397940</td>
#       <td id="T_670fa_row0_col4" class="data row0 col4" >0.518023</td>
#     </tr>
#     <tr>
#       <th id="T_670fa_level0_row1" class="row_heading level0 row1" >fear</th>
#       <td id="T_670fa_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_670fa_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_670fa_row1_col2" class="data row1 col2" >0.522879</td>
#       <td id="T_670fa_row1_col3" class="data row1 col3" >0.522879</td>
#       <td id="T_670fa_row1_col4" class="data row1 col4" >0.680664</td>
#     </tr>
#     <tr>
#       <th id="T_670fa_level0_row2" class="row_heading level0 row2" >in</th>
#       <td id="T_670fa_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_670fa_row2_col1" class="data row2 col1" >1.000000</td>
#       <td id="T_670fa_row2_col2" class="data row2 col2" >0.397940</td>
#       <td id="T_670fa_row2_col3" class="data row2 col3" >0.397940</td>
#       <td id="T_670fa_row2_col4" class="data row2 col4" >0.518023</td>
#     </tr>
#   </tbody>
# </table>

# %%
## query length
calc_query_data(query , get_docs)[1]
# Out:
# 0.7681892236094847

# %%
## product
calc_query_data(query , get_docs)[2].style.background_gradient(cmap = "Reds" , axis= 1)
# Out:
# <style type="text/css">
# #T_83a60_row0_col0, #T_83a60_row1_col0, #T_83a60_row2_col0, #T_83a60_row3_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_83a60_row0_col1, #T_83a60_row0_col2, #T_83a60_row1_col1, #T_83a60_row1_col2, #T_83a60_row2_col1, #T_83a60_row2_col2, #T_83a60_row3_col1, #T_83a60_row3_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_83a60">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83a60_level0_col0" class="col_heading level0 col0" >DOC_10</th>
#       <th id="T_83a60_level0_col1" class="col_heading level0 col1" >DOC_7</th>
#       <th id="T_83a60_level0_col2" class="col_heading level0 col2" >DOC_8</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83a60_level0_row0" class="row_heading level0 row0" >fools</th>
#       <td id="T_83a60_row0_col0" class="data row0 col0" >0.186362</td>
#       <td id="T_83a60_row0_col1" class="data row0 col1" >0.168486</td>
#       <td id="T_83a60_row0_col2" class="data row0 col2" >0.168486</td>
#     </tr>
#     <tr>
#       <th id="T_83a60_level0_row1" class="row_heading level0 row1" >fear</th>
#       <td id="T_83a60_row1_col0" class="data row1 col0" >0.321755</td>
#       <td id="T_83a60_row1_col1" class="data row1 col1" >0.290892</td>
#       <td id="T_83a60_row1_col2" class="data row1 col2" >0.290892</td>
#     </tr>
#     <tr>
#       <th id="T_83a60_level0_row2" class="row_heading level0 row2" >in</th>
#       <td id="T_83a60_row2_col0" class="data row2 col0" >0.186362</td>
#       <td id="T_83a60_row2_col1" class="data row2 col1" >0.168486</td>
#       <td id="T_83a60_row2_col2" class="data row2 col2" >0.168486</td>
#     </tr>
#     <tr>
#       <th id="T_83a60_level0_row3" class="row_heading level0 row3" >Sum</th>
#       <td id="T_83a60_row3_col0" class="data row3 col0" >0.694479</td>
#       <td id="T_83a60_row3_col1" class="data row3 col1" >0.627864</td>
#       <td id="T_83a60_row3_col2" class="data row3 col2" >0.627864</td>
#     </tr>
#   </tbody>
# </table>
